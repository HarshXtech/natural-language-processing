# %%
import pandas as pd
df = pd.read_csv('SMSSpamCollection.txt', sep='\t', names=['labels', 'messages'])

# %%
df
# Out:
#      labels                                           messages
# 0       ham  Go until jurong point, crazy.. Available only ...
# 1       ham                      Ok lar... Joking wif u oni...
# 2      spam  Free entry in 2 a wkly comp to win FA Cup fina...
# 3       ham  U dun say so early hor... U c already then say...
# 4       ham  Nah I don't think he goes to usf, he lives aro...
# ...     ...                                                ...
# 5567   spam  This is the 2nd time we have tried 2 contact u...
# 5568    ham               Will ü b going to esplanade fr home?
# 5569    ham  Pity, * was in mood for that. So...any other s...
# 5570    ham  The guy did some bitching but I acted like i'd...
# 5571    ham                         Rofl. Its true to its name
#
# [5572 rows x 2 columns]

# %%
import nltk
from nltk.corpus import stopwords
from nltk.stem import PorterStemmer, WordNetLemmatizer
import re

# %%
ps = PorterStemmer()
lemmatizer = WordNetLemmatizer()

stem_corpus = []
lem_corpus = []

for i in (df['messages']):
    review = re.sub('[^a-zA-Z]', ' ', i)
    review = review.lower()
    review = review.split()
    stem_review = [ps.stem(word) for word in review if word not in stopwords.words('english') ]
    lem_review = [lemmatizer.lemmatize(word) for word in review if word not in stopwords.words('english') ]
    stem_review = ' '.join(stem_review)
    lem_review = ' '.join(lem_review)
    stem_corpus.append(stem_review)
    lem_corpus.append(lem_review)

# %%
from sklearn.feature_extraction.text import TfidfVectorizer

# %%
stem_vectorizer = TfidfVectorizer(max_features=100)
lem_vectorizer = TfidfVectorizer(max_features=100)

# %%
x_stem = stem_vectorizer.fit_transform(stem_corpus).toarray()
x_lem = lem_vectorizer.fit_transform(lem_corpus).toarray()

# %%
import numpy as np

np.set_printoptions(edgeitems=100, linewidth=1000, formatter=dict(float=lambda x : '%.3g' % x))

# %% [markdown]
# ### n Grams

# %%
stem_vectorizer = TfidfVectorizer(max_features=100, ngram_range=(2, 2))
lem_vectorizer = TfidfVectorizer(max_features=100, ngram_range=(2, 2))

x_stem = stem_vectorizer.fit_transform(stem_corpus).toarray()
y_stem = lem_vectorizer.fit_transform(lem_corpus).toarray()

# %%
stem_vectorizer.vocabulary_
# Out:
# {'free entri': np.int64(31),
#  'claim call': np.int64(16),
#  'call claim': np.int64(3),
#  'free call': np.int64(30),
#  'chanc win': np.int64(15),
#  'txt word': np.int64(87),
#  'let know': np.int64(53),
#  'go home': np.int64(35),
#  'pleas call': np.int64(67),
#  'lt gt': np.int64(57),
#  'miss call': np.int64(58),
#  'want go': np.int64(97),
#  'like lt': np.int64(54),
#  'sorri call': np.int64(79),
#  'call later': np.int64(8),
#  'ur award': np.int64(88),
#  'hi hi': np.int64(46),
#  'call custom': np.int64(4),
#  'custom servic': np.int64(23),
#  'cash prize': np.int64(14),
#  'po box': np.int64(68),
#  'tri contact': np.int64(84),
#  'draw show': np.int64(28),
#  'show prize': np.int64(78),
#  'prize guarante': np.int64(72),
#  'guarante call': np.int64(42),
#  'valid hr': np.int64(95),
#  'select receiv': np.int64(75),
#  'privat account': np.int64(70),
#  'account statement': np.int64(0),
#  'statement show': np.int64(80),
#  'call identifi': np.int64(5),
# ...

# %%
lem_vectorizer.vocabulary_
# Out:
# {'free entry': np.int64(32),
#  'claim call': np.int64(16),
#  'call claim': np.int64(3),
#  'claim code': np.int64(17),
#  'free call': np.int64(31),
#  'chance win': np.int64(15),
#  'txt word': np.int64(89),
#  'let know': np.int64(54),
#  'please call': np.int64(68),
#  'lt gt': np.int64(58),
#  'want go': np.int64(97),
#  'like lt': np.int64(55),
#  'sorry call': np.int64(80),
#  'call later': np.int64(9),
#  'ur awarded': np.int64(90),
#  'call free': np.int64(5),
#  'hi hi': np.int64(46),
#  'call customer': np.int64(4),
#  'customer service': np.int64(24),
#  'guaranteed cash': np.int64(42),
#  'cash prize': np.int64(14),
#  'po box': np.int64(70),
#  'trying contact': np.int64(86),
#  'draw show': np.int64(29),
#  'show prize': np.int64(79),
#  'prize guaranteed': np.int64(74),
#  'guaranteed call': np.int64(41),
#  'valid hr': np.int64(95),
#  'selected receive': np.int64(76),
#  'private account': np.int64(72),
#  'account statement': np.int64(0),
# ...
